# %% [markdown]
# <h1> Coursera - IBM Datascience Capstone - Week 3 </h1>

# %%
#  make sure libs are installed:
# !pip install pandas
# !pip install requests
# !pip install bs4

#  imports required:
import pandas as pd
import requests
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: pandas in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (1.2.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from pandas) (1.20.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests) (1.26.4)
# Requirement already satisfied: bs4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from beautifulsoup4->bs4) (2.0.1)

# %% [markdown]
# <h2> Get Post Code Data </h2>

# %%
#  get table from url:
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
html_data = requests.get(url).text

#  Convert to Beautiful soup object:
soup = BeautifulSoup(html_data, "html5lib")
tables = soup.find_all('table')

#  after looking at results, id 0 is the correct table.
table_id = 0

#  need to loop through each row and column to pull apart post code and location:
post_codes = pd.DataFrame(columns=['PostalCode','Borough','Neighborhood'])
table_rows = tables[table_id].find_all('td')

for row in table_rows:
    post_code = (row.p.b.text)
    cell_content =row.span.text.split("(")
    if len(cell_content) > 1:
        borough = cell_content[0]
        neighborhood = cell_content[1].replace(")","").replace("/", ", ")
        post_codes = post_codes.append({"PostalCode":post_code, "Borough": borough, "Neighborhood":neighborhood}, ignore_index = True)

# %%
post_codes.head()
# Out:
#   PostalCode           Borough                        Neighborhood
# 0        M3A        North York                           Parkwoods
# 1        M4A        North York                    Victoria Village
# 2        M5A  Downtown Toronto         Regent Park ,  Harbourfront
# 3        M6A        North York  Lawrence Manor ,  Lawrence Heights
# 4        M7A      Queen's Park       Ontario Provincial Government

# %% [markdown]
# <h2> Get Location Data </h2>

# %%
geospatial_data = pd.read_csv('https://cocl.us/Geospatial_data')
geospatial_data.columns = ['PostalCode', 'Latitude', 'Longitude']
geospatial_data.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
post_codes_locations = pd.merge(post_codes, geospatial_data, on="PostalCode")
post_codes_locations.head()
# Out:
#   PostalCode           Borough                        Neighborhood   Latitude  \
# 0        M3A        North York                           Parkwoods  43.753259
# 1        M4A        North York                    Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park ,  Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor ,  Lawrence Heights  43.718518
# 4        M7A      Queen's Park       Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# <h2> Explore Clustering </h2>

# %% [markdown]
# The below cell will stipulate secret codes to be used in the url generation (hidden)

# %%
# @hidden_cell

# %%
toronto_boroughs = post_codes_locations[post_codes_locations['Borough'].str.contains("Toronto")].reset_index()
toronto_boroughs.head()
# Out:
#    index PostalCode           Borough                 Neighborhood   Latitude  \
# 0      2        M5A  Downtown Toronto  Regent Park ,  Harbourfront  43.654260
# 1      9        M5B  Downtown Toronto     Garden District, Ryerson  43.657162
# 2     15        M5C  Downtown Toronto               St. James Town  43.651494
# 3     19        M4E      East Toronto                  The Beaches  43.676357
# 4     20        M5E  Downtown Toronto                  Berczy Park  43.644771
#
#    Longitude
# 0 -79.360636
# 1 -79.378937
# 2 -79.375418
# 3 -79.293031
# 4 -79.373306

# %% [markdown]
# <h3> Import ability to call FourSquare API: </h3>

# %%
import requests

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_borough_venues = getNearbyVenues(names = toronto_boroughs['Neighborhood'],
                                         latitudes = toronto_boroughs['Latitude'],
                                         longitudes = toronto_boroughs['Longitude']
                                        )

# %%
toronto_borough_venues.head()
# Out:
#                   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park ,  Harbourfront               43.65426              -79.360636
# 1  Regent Park ,  Harbourfront               43.65426              -79.360636
# 2  Regent Park ,  Harbourfront               43.65426              -79.360636
# 3  Regent Park ,  Harbourfront               43.65426              -79.360636
# 4  Regent Park ,  Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4          Impact Kitchen       43.656369       -79.356980
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4           Restaurant

# %%
toronto_one_hot = pd.get_dummies(toronto_borough_venues[['Venue Category']], prefix="", prefix_sep="")

#  one hot has removed neighborhood names:
toronto_one_hot["Neighborhood"] = toronto_borough_venues['Neighborhood']
#  rearrange to make borough first:
fixed_order = [toronto_one_hot.columns[-1]] + list(toronto_one_hot.columns[:-1])
toronto_one_hot = toronto_one_hot[fixed_order]

# %%
#  normalise results to be an average value for borough:
toronto_grouped = toronto_one_hot.groupby("Neighborhood").mean().reset_index()
toronto_grouped
# Out:
#                                          Neighborhood  Yoga Studio   Airport  \
# 0                                         Berczy Park     0.000000  0.000000
# 
# 8                 0.000000            0.000000          0.000000  0.000000
# 9                 0.000000            0.000000          0.000000  0.000000
# 10                0.000000            0.000000          0.000000  0.000000
# 11                0.000000            0.000000          0.000000  0.000000
# 12                0.000000            0.000000          0.000000  0.000000
# 13                0.000000            0.000000          0.000000  0.250000
# 14                0.000000            0.000000          0.000000  0.000000
# 15                0.000000            0.000000          0.000000  0.000000
# 16                0.000000            0.000000          0.000000  0.000000
# 17                0.000000            0.000000          0.000000  0.000000
# 18                0.033333            0.000000          0.000000  0.000000
# 19                0.000000            0.000000          0.000000  0.000000
# 20                0.000000            0.000000          0.000000  0.000000
# 21                0.000000            0.000000          0.000000  0.000000
# 22                0.000000            0.000000          0.000000  0.000000
# 23                0.000000            0.000000          0.000000  0.000000
# 24                0.000000            0.000000          0.000000  0.000000
# 25                0.000000            0.000000          0.000000  0.250000
# 26                0.000000            0.000000          0.000000  0.000000
# 27                0.000000            0.000000          0.000000  0.000000
# 28                0.000000            0.000000          0.000000  0.000000
# 29                0.000000            0.000000          0.000000  0.000000
# 30                0.000000            0.000000          0.000000  0.000000
# 31                0.000000            0.000000          0.000000  0.000000
# 32                0.000000            0.000000          0.000000  0.000000
# 33                0.000000            0.000000          0.000000  0.250000
# 34                0.000000            0.000000          0.000000  0.000000
# 35                0.000000            0.033333          0.000000  0.033333
# 36                0.000000            0.000000          0.000000  0.000000
# 37                0.000000            0.000000          0.000000  0.000000
#
#     Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0        0.000000                       0.033333          0.000000
# 1        0.000000                       0.000000          0.000000
# 2        0.000000                       0.000000          0.000000
# 3        0.000000                       0.033333          0.000000
# 4        0.000000                       0.000000          0.000000
# 5        0.000000                       0.000000          0.000000
# 6        0.000000                       0.000000          0.000000
# 7        0.000000                       0.000000          0.000000
# 8        0.000000                       0.000000          0.000000
# 9        0.000000                       0.000000          0.000000
# 10       0.000000                       0.000000          0.000000
# 11       0.000000                       0.033333          0.000000
# 12       0.000000                       0.033333          0.000000
# 13       0.000000                       0.000000          0.000000
# 14       0.000000                       0.000000          0.000000
# 15       0.033333                       0.000000          0.000000
# 16       0.000000                       0.000000          0.000000
# 17       0.000000                       0.000000          0.000000
# 18       0.000000                       0.033333          0.000000
# 19       0.000000                       0.000000          0.000000
# 20       0.000000                       0.033333          0.000000
# 21       0.000000                       0.000000          0.000000
# 22       0.000000                       0.000000          0.000000
# 23       0.000000                       0.000000          0.000000
# 24       0.000000                       0.033333          0.000000
# 25       0.000000                       0.000000          0.000000
# 26       0.000000                       0.000000          0.000000
# 27       0.000000                       0.033333          0.000000
# 28       0.000000                       0.000000          0.000000
# 29       0.000000                       0.000000          0.000000
# 30       0.000000                       0.000000          0.000000
# 31       0.000000                       0.000000          0.000000
# 32       0.000000                       0.000000          0.000000
# 33       0.000000                       0.000000          0.000000
# 34       0.000000                       0.000000          0.000000
# 35       0.000000                       0.000000          0.000000
# 36       0.033333                       0.000000          0.000000
# 37       0.000000                       0.000000          0.033333
#
#     Vietnamese Restaurant  Wine Bar
# 0                0.000000  0.000000
# 1                0.000000  0.000000
# 2                0.000000  0.000000
# 3                0.000000  0.000000
# 4                0.000000  0.000000
# 5                0.000000  0.000000
# 6                0.000000  0.033333
# 7                0.000000  0.000000
# 8                0.000000  0.000000
# 9                0.000000  0.000000
# 10               0.000000  0.000000
# 11               0.000000  0.000000
# 12               0.000000  0.033333
# 13               0.000000  0.000000
# 14               0.000000  0.000000
# 15               0.000000  0.000000
# 16               0.000000  0.000000
# 17               0.000000  0.000000
# 18               0.066667  0.033333
# 19               0.000000  0.000000
# 20               0.066667  0.033333
# 21               0.000000  0.000000
# 22               0.000000  0.000000
# 23               0.000000  0.000000
# 24               0.000000  0.000000
# 25               0.000000  0.000000
# 26               0.000000  0.000000
# 27               0.000000  0.000000
# 28               0.000000  0.000000
# 29               0.000000  0.000000
# 30               0.000000  0.000000
# 31               0.071429  0.000000
# 32               0.000000  0.000000
# 33               0.000000  0.000000
# 34               0.000000  0.000000
# 35               0.000000  0.000000
# 36               0.000000  0.033333
# 37               0.000000  0.000000
#
# [38 rows x 190 columns]

# %%
#  to match past assignment we will use k-means to cluster boroughs:
# import k-means from clustering stage
import numpy as np
#!pip install scikit-learn
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import sklearn.utils
sklearn.utils.check_random_state(1000)
# Out:
# RandomState(MT19937) at 0x7F9D17A6D8D0

# %%
#  pre-process data for kMeans:
toronto_clustered = toronto_grouped.drop("Neighborhood",1)
toronto_clustered = np.nan_to_num(toronto_clustered)
toronto_clustered = StandardScaler().fit_transform(toronto_clustered)

#  Compute DBSCAN:
kcluster = 6
kmeans = KMeans(n_clusters=kcluster, random_state = 0).fit(toronto_clustered)

# %% [markdown]
# <h3> Get Top Venues </h3>

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)
    
neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park    Seafood Restaurant
# 1   Brockton ,  Parkdale Village ,  Exhibition Place                  Café
# 2  CN Tower ,  King and Spadina ,  Railway Lands ...       Airport Service
# 3                                 Central Bay Street           Coffee Shop
# 4                                           Christie         Grocery Store
#
#   2nd Most Common Venue 3rd Most Common Venue  4th Most Common Venue  \
# 0              Beer Bar           Coffee Shop           Cocktail Bar
# 1           Coffee Shop        Breakfast Spot  Performing Arts Venue
# 2        Airport Lounge      Airport Terminal        Harbor / Marina
# 3    Italian Restaurant                  Café            Yoga Studio
# 4                  Café                  Park             Restaurant
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0          Farmers Market           Fish Market    Basketball Stadium
# 1  Furniture / Home Store     Convenience Store               Stadium
# 2           Boat or Ferry           Coffee Shop   Rental Car Location
# 3              Comic Shop       Bubble Tea Shop        Sandwich Place
# 4              Baby Store           Candy Store             Nightclub
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0                Bistro      French Restaurant               Fountain
# 1                   Bar              Nightclub                 Bakery
# 2      Sculpture Garden                  Plane                Airport
# 3      Ramen Restaurant  Portuguese Restaurant                   Park
# 4    Italian Restaurant     Athletics & Sports            Coffee Shop

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_merged = toronto_boroughs
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged.head()
# Out:
#    index PostalCode           Borough                 Neighborhood   Latitude  \
# 0      2        M5A  Downtown Toronto  Regent Park ,  Harbourfront  43.654260
# 1      9        M5B  Downtown Toronto     Garden District, Ryerson  43.657162
# 2     15        M5C  Downtown Toronto               St. James Town  43.651494
# 3     19        M4E      East Toronto                  The Beaches  43.676357
# 4     20        M5E  Downtown Toronto                  Berczy Park  43.644771
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.360636             0.0           Coffee Shop                  Park
# 1 -79.378937             0.0                  Café        Clothing Store
# 2 -79.375418             4.0                  Café             Gastropub
# 3 -79.293031             0.0     Health Food Store                 Trail
# 4 -79.373306             4.0    Seafood Restaurant              Beer Bar
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                Bakery        Breakfast Spot                  Café
# 1               Theater      Ramen Restaurant         Shopping Mall
# 2           Coffee Shop            Restaurant        Farmers Market
# 3                   Pub           Yoga Studio           Music Venue
# 4           Coffee Shop          Cocktail Bar        Farmers Market
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0            Restaurant        Chocolate Shop                   Pub
# 1         Burrito Place          Burger Joint    Mexican Restaurant
# 2            Food Truck             BBQ Joint              Creperie
# 3   Martial Arts School           Men's Store         Metro Station
# 4           Fish Market    Basketball Stadium                Bistro
#
#    9th Most Common Venue     10th Most Common Venue
# 0  Performing Arts Venue                Yoga Studio
# 1         Sandwich Place       Fast Food Restaurant
# 2                   Park               Cocktail Bar
# 3     Mexican Restaurant  Middle Eastern Restaurant
# 4      French Restaurant                   Fountain

# %% [markdown]
# <h3> Folium Map </h3>

# %%
# !pip install folium
import folium # map rendering library

import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: branca in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.25.1)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.10)

# %%
toronto_merged = toronto_merged.dropna()

# %%
# create map
map_clusters = folium.Map(location=[toronto_merged['Latitude'][0], toronto_merged['Longitude'][0]], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
#map_clusters

# %%
#  CLuster 0 = Parks and Cafes
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    PostalCode  Longitude  Cluster Labels 1st Most Common Venue  \
# 0         M5A -79.360636             0.0           Coffee Shop
# 1         M5B -79.378937             0.0                  Café
# 3         M4E -79.293031             0.0     Health Food Store
# 5         M5G -79.387383             0.0           Coffee Shop
# 6         M6G -79.422564             0.0         Grocery Store
# 8         M6H -79.442259             0.0              Pharmacy
# 9         M4J -79.338106             0.0           Pizza Place
# 12        M4K -79.352188             0.0      Greek Restaurant
# 14        M6K -79.428191             0.0                  Café
# 15        M4L -79.315572             0.0                  Park
# 17        M4M -79.340923             0.0           Coffee Shop
# 18        M4N -79.388790             0.0                  Park
# 19        M5N -79.416936             0.0                Garden
# 20        M4P -79.390197             0.0      Department Store
# 21        M5P -79.411307             0.0                 Trail
# 23        M4R -79.405678             0.0        Clothing Store
# 24        M5R -79.405678             0.0        Sandwich Place
# 25        M6R -79.456325             0.0        Breakfast Spot
# 26        M4S -79.388790             0.0          Dessert Shop
# 28        M6S -79.484450             0.0           Coffee Shop
# 31        M4V -79.400049             0.0           Coffee Shop
# 32        M5V -79.394420             0.0       Airport Service
# 33        M4W -79.377529             0.0                  Park
# 35        M4X -79.367675             0.0                  Café
# 37        M4Y -79.383160             0.0           Coffee Shop
# 38        M7Y -79.321558             0.0    Light Rail Station
#
#    2nd Most Common Venue       3rd Most Common Venue  4th Most Common Venue  \
# 0                   Park                      Bakery         Breakfast Spot
# 1         Clothing Store                     Theater       Ramen Restaurant
# 3                  Trail                         Pub            Yoga Studio
# 5     Italian Restaurant                        Café            Yoga Studio
# 6                   Café                        Park             Restaurant
# 8                 Bakery               Grocery Store                   Café
# 9           Intersection               Metro Station                   Park
# 12        Ice Cream Shop          Italian Restaurant            Yoga Studio
# 14           Coffee Shop              Breakfast Spot  Performing Arts Venue
# 15  Fast Food Restaurant                  Board Shop                    Pub
# 17                Bakery                        Café    American Restaurant
# 18           Swim School                    Bus Line            Yoga Studio
# 19           Yoga Studio                      Museum                 Market
# 20        Breakfast Spot  Construction & Landscaping                  Hotel
# 21         Jewelry Store            Sushi Restaurant               Bus Line
# 23           Coffee Shop                 Yoga Studio     Mexican Restaurant
# 24                  Café                 Coffee Shop            Pizza Place
# 25             Gift Shop            Cuban Restaurant           Dessert Shop
# 26    Italian Restaurant                         Gym            Pizza Place
# 28                  Café          Italian Restaurant                    Pub
# 31           Pizza Place                        Bank       Sushi Restaurant
# 32        Airport Lounge            Airport Terminal        Harbor / Marina
# 33            Playground                       Trail                 Museum
# 35            Restaurant                 Coffee Shop     Italian Restaurant
# 37        Breakfast Spot                 Escape Room            Men's Store
# 38           Yoga Studio               Auto Workshop          Garden Center
#
#      5th Most Common Venue    6th Most Common Venue 7th Most Common Venue  \
# 0                     Café               Restaurant        Chocolate Shop
# 1            Shopping Mall            Burrito Place          Burger Joint
# 3              Music Venue      Martial Arts School           Men's Store
# 5               Comic Shop          Bubble Tea Shop        Sandwich Place
# 6               Baby Store              Candy Store             Nightclub
# 8                  Brewery                     Pool                  Park
# 9        Convenience Store      Martial Arts School           Men's Store
# 12  Furniture / Home Store  Fruit & Vegetable Store                   Spa
# 14  Furniture / Home Store        Convenience Store               Stadium
# 15                 Brewery           Sandwich Place          Liquor Store
# 17             Yoga Studio                Pet Store               Brewery
# 18           Movie Theater      Martial Arts School           Men's Store
# 19     Martial Arts School              Men's Store         Metro Station
# 20                    Park        Food & Drink Shop        Sandwich Place
# 21             Yoga Studio            Movie Theater   Martial Arts School
# 23                     Spa     Fast Food Restaurant   Sporting Goods Shop
# 24       Indian Restaurant               Donut Shop          Burger Joint
# 25              Restaurant                Bookstore               Dog Run
# 26             Coffee Shop                     Café        Sandwich Place
# 28             Pizza Place         Sushi Restaurant         Burrito Place
# 31             Supermarket                      Pub   Fried Chicken Joint
# 32           Boat or Ferry              Coffee Shop   Rental Car Location
# 33                  Market      Martial Arts School           Men's Store
# 35                  Bakery     Taiwanese Restaurant  Caribbean Restaurant
# 37               Bookstore       Mexican Restaurant       Bubble Tea Shop
# 38                  Garden     Fast Food Restaurant        Farmers Market
#
#         8th Most Common Venue      9th Most Common Venue  \
# 0                         Pub      Performing Arts Venue
# 1          Mexican Restaurant             Sandwich Place
# 3               Metro Station         Mexican Restaurant
# 5            Ramen Restaurant      Portuguese Restaurant
# 6          Italian Restaurant         Athletics & Sports
# 8   Middle Eastern Restaurant                Supermarket
# 9          Mexican Restaurant  Middle Eastern Restaurant
# 12             Cosmetics Shop                  Bookstore
# 14                        Bar                  Nightclub
# 15                  Pet Store          Fish & Chips Shop
# 17         Seafood Restaurant                Cheese Shop
# 18              Metro Station         Mexican Restaurant
# 19         Mexican Restaurant  Middle Eastern Restaurant
# 20                Yoga Studio         Mexican Restaurant
# 21                Men's Store              Metro Station
# 23         Salon / Barbershop                       Café
# 24               Liquor Store                  BBQ Joint
# 25         Italian Restaurant                        Bar
# 26           Sushi Restaurant               Gourmet Shop
# 28                        Bar          French Restaurant
# 31                 Restaurant        American Restaurant
# 32           Sculpture Garden                      Plane
# 33              Metro Station         Mexican Restaurant
# 35                     Market               Liquor Store
# 37               Burger Joint              Burrito Place
# 38                       Park                Pizza Place
#
#         10th Most Common Venue
# 0                  Yoga Studio
# 1         Fast Food Restaurant
# 3    Middle Eastern Restaurant
# 5                         Park
# 6                  Coffee Shop
# 8                          Bar
# 9   Modern European Restaurant
# 12                     Brewery
# 14                      Bakery
# 15           Food & Drink Shop
# 17              Clothing Store
# 18   Middle Eastern Restaurant
# 19  Modern European Restaurant
# 20   Middle Eastern Restaurant
# 21          Mexican Restaurant
# 23                       Diner
# 24   Middle Eastern Restaurant
# 25               Movie Theater
# 26                    Pharmacy
# 28               Smoothie Shop
# 31          Light Rail Station
# 32                     Airport
# 33   Middle Eastern Restaurant
# 35                  Beer Store
# 37                        Café
# 38                  Comic Shop

# %%
#  CLuster 4 = Food Places
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    PostalCode  Longitude  Cluster Labels 1st Most Common Venue  \
# 2         M5C -79.375418             4.0                  Café
# 4         M5E -79.373306             4.0    Seafood Restaurant
# 7         M5H -79.384568             4.0           Coffee Shop
# 11        M6J -79.419750             4.0                   Bar
# 13        M5K -79.381576             4.0                  Café
# 16        M5L -79.379817             4.0                  Café
# 34        M5W -79.374846             4.0    Seafood Restaurant
# 36        M5X -79.382280             4.0                  Café
#
#    2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 2              Gastropub            Coffee Shop            Restaurant
# 4               Beer Bar            Coffee Shop          Cocktail Bar
# 7                   Café     Seafood Restaurant  Gym / Fitness Center
# 11      Asian Restaurant  Vietnamese Restaurant           Men's Store
# 13           Coffee Shop             Restaurant                Bakery
# 16                 Hotel            Coffee Shop             Gastropub
# 34                  Café           Cocktail Bar        Farmers Market
# 36           Coffee Shop             Restaurant                 Hotel
#
#    5th Most Common Venue    6th Most Common Venue 7th Most Common Venue  \
# 2         Farmers Market               Food Truck             BBQ Joint
# 4         Farmers Market              Fish Market    Basketball Stadium
# 7       Sushi Restaurant               Steakhouse             Speakeasy
# 11               Brewery             Cocktail Bar           Coffee Shop
# 13   Japanese Restaurant                 Wine Bar                   Gym
# 16   American Restaurant               Restaurant              Wine Bar
# 34              Beer Bar  Comfort Food Restaurant              Creperie
# 36    Seafood Restaurant                 Wine Bar                Bakery
#
#    8th Most Common Venue   9th Most Common Venue 10th Most Common Venue
# 2               Creperie                    Park           Cocktail Bar
# 4                 Bistro       French Restaurant               Fountain
# 7             Smoke Shop    Fast Food Restaurant             Restaurant
# 11      Cuban Restaurant       French Restaurant       Greek Restaurant
# 13                 Hotel                  Museum          Deli / Bodega
# 16    Seafood Restaurant          Sandwich Place                    Pub
# 34            Restaurant             Coffee Shop           Concert Hall
# 36                   Gym  Gluten-free Restaurant              Gastropub
